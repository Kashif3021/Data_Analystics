# %%
import pandas as pd

# %%
# dir(pd)

# %% [markdown]
# ## Data loading

# %%
df = pd.read_csv("retail supermarket-.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### shape,shape is a attribute of data to show no of rows and columns

# %%
# shape,shape is a attribute of data to show no of rows and columns
df.shape
# print(type(df.shape))
# print(df.shape)
# Out:
# (9994, 13)

# %% [markdown]
# ## df.info() it used to show all data like data type, missing values.

# %%
# df.info() it used to show all data like data type, missing values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# df.dtypes. it used to show data types of any data.
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# df.head(). it used to show no of rows of a data from start
# defalut value rows 5 
# we can show own no of rows by enter no 
# df.head()

# %%
df.head(15)
# Out:
#          Ship Mode      Segment        Country             City  \
# 0     Second Class     Consumer  United States        Henderson
# 1     Second Class     Consumer  United States        Henderson
# 2     Second Class    Corporate  United States      Los Angeles
# 3   Standard Class     Consumer  United States  Fort Lauderdale
# 4   Standard Class     Consumer  United States  Fort Lauderdale
# 5   Standard Class     Consumer  United States      Los Angeles
# 6   Standard Class     Consumer  United States      Los Angeles
# 7   Standard Class     Consumer  United States      Los Angeles
# 8   Standard Class     Consumer  United States      Los Angeles
# 9   Standard Class     Consumer  United States      Los Angeles
# 10  Standard Class     Consumer  United States      Los Angeles
# 11  Standard Class     Consumer  United States      Los Angeles
# 12  Standard Class     Consumer  United States          Concord
# 13  Standard Class     Consumer  United States          Seattle
# ...

# %%
# df.tail(), it used to show data row of a data form botton
# we can show no of rows by entering no
# df.tail()

# %%
df.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %%
# we access only one column 
# df["key_name_of_column"]
df['Sales']
# Out:
# 0       261.9600
# 1       731.9400
# 2        14.6200
# 3       957.5775
# 4        22.3680
#           ...
# 9989     25.2480
# 9990     91.9600
# 9991    258.5760
# 9992     29.6000
# 9993    243.1600
# Name: Sales, Length: 9994, dtype: float64

# %%
# we access multiple columns 
# df[["key_name_of_column","key_name_of_column","key_name_of_column"]]
df[['Sales','Country','Region']]
# Out:
#          Sales        Country Region
# 0     261.9600  United States  South
# 1     731.9400  United States  South
# 2      14.6200  United States   West
# 3     957.5775  United States  South
# 4      22.3680  United States  South
# ...        ...            ...    ...
# 9989   25.2480  United States  South
# 9990   91.9600  United States   West
# 9991  258.5760  United States   West
# 9992   29.6000  United States   West
# 9993  243.1600  United States   West
#
# [9994 rows x 3 columns]

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ## indexing in Pandas

# %% [markdown]
# ### loc(Label-based indexing) Syntax:df.loc[row_labe1,column_label]

# %%
# we can see specific row recorad on label base indexing.
df.loc[0]
# Out:
# Ship Mode        Second Class
# Segment              Consumer
# Country         United States
# City                Henderson
# State                Kentucky
# Postal Code             42420
# Region                  South
# Category            Furniture
# Sub-Category        Bookcases
# Sales                  261.96
# Quantity                    2
# Discount                  0.0
# Profit                41.9136
# Name: 0, dtype: object

# %%
df.loc[4]
# Out:
# Ship Mode        Standard Class
# Segment                Consumer
# Country           United States
# City            Fort Lauderdale
# State                   Florida
# Postal Code               33311
# Region                    South
# Category        Office Supplies
# Sub-Category            Storage
# Sales                    22.368
# Quantity                      2
# Discount                    0.2
# Profit                   2.5164
# Name: 4, dtype: object

# %%
df.loc[4,'State'] # row specific value
# Out:
# 'Florida'

# %% [markdown]
# ### iloc(integer-based indexing) Syntax:df.iloc[row_index,column_index]

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.iloc[0]
# Out:
# Ship Mode        Second Class
# Segment              Consumer
# Country         United States
# City                Henderson
# State                Kentucky
# Postal Code             42420
# Region                  South
# Category            Furniture
# Sub-Category        Bookcases
# Sales                  261.96
# Quantity                    2
# Discount                  0.0
# Profit                41.9136
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Ship Mode        Second Class
# Segment              Consumer
# Country         United States
# City                Henderson
# State                Kentucky
# Postal Code             42420
# Region                  South
# Category            Furniture
# Sub-Category           Chairs
# Sales                  731.94
# Quantity                    3
# Discount                  0.0
# Profit                219.582
# Name: 1, dtype: object

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.iloc[2,4]
# Out:
# 'California'

# %% [markdown]
# # Slicing in pandas

# %% [markdown]
# ## loc(Label-based Slicing) Syntax:df.loc[row_labe1:row_label]

# %%
# Key Difference:
# With .loc[], the end label is inclusive (included in the slice).
# With .iloc[], the end position is exclusive (not included in the slice),
# consistent with Python's standard slicing.

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.loc[0:4]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.loc[1:2]
# Out:
#       Ship Mode    Segment        Country         City       State  \
# 1  Second Class   Consumer  United States    Henderson    Kentucky
# 2  Second Class  Corporate  United States  Los Angeles  California
#
#    Postal Code Region         Category Sub-Category   Sales  Quantity  \
# 1        42420  South        Furniture       Chairs  731.94         3
# 2        90036   West  Office Supplies       Labels   14.62         2
#
#    Discount    Profit
# 1       0.0  219.5820
# 2       0.0    6.8714

# %%
df.iloc[0:4]
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310

# %%
df.iloc[1:2]
# Out:
#       Ship Mode   Segment        Country       City     State  Postal Code  \
# 1  Second Class  Consumer  United States  Henderson  Kentucky        42420
#
#   Region   Category Sub-Category   Sales  Quantity  Discount   Profit
# 1  South  Furniture       Chairs  731.94         3       0.0  219.582

# %% [markdown]
# # logical Operator in Pandas

# %%
# Logical Operators in Pandas:
# * & (and)
# * | (or)
# * ~ (not)    tilde

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df["Region"]
# Out:
# 0       South
# 1       South
# 2        West
# 3       South
# 4       South
#         ...
# 9989    South
# 9990     West
# 9991     West
# 9992     West
# 9993     West
# Name: Region, Length: 9994, dtype: object

# %%
# unique, it is used to find out unique name  
#  it used where repeating valves/element
# it is used where catogary
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
# if we checking the no of region like south,west then we used "==" equal operator
# Syntax: df["Region"] == "Target_element_name"
# if we want to see tabular form the above syntax then 
#  df[df["Region"] == "Target_element_name"]

# %%
df['Region']=='East'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# Name: Region, Length: 9994, dtype: bool

# %%
df[df['Region']=='East']
# Out:
#            Ship Mode   Segment        Country          City         State  \
# 23      Second Class  Consumer  United States  Philadelphia  Pennsylvania
# 27    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 28    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 29    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 30    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# ...              ...       ...            ...           ...           ...
# 9968  Standard Class  Consumer  United States    Plainfield    New Jersey
# 9969  Standard Class  Consumer  United States    Plainfield    New Jersey
# 9981     First Class  Consumer  United States     Fairfield          Ohio
# 9984  Standard Class  Consumer  United States    Long Beach      New York
# 9985  Standard Class  Consumer  United States    Long Beach      New York
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# ...

# %%
# now if we want to write the desire data then we save in varibale then werite

East = df[df['Region']=='East']
East
# Out:
#            Ship Mode   Segment        Country          City         State  \
# 23      Second Class  Consumer  United States  Philadelphia  Pennsylvania
# 27    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 28    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 29    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# 30    Standard Class  Consumer  United States  Philadelphia  Pennsylvania
# ...              ...       ...            ...           ...           ...
# 9968  Standard Class  Consumer  United States    Plainfield    New Jersey
# 9969  Standard Class  Consumer  United States    Plainfield    New Jersey
# 9981     First Class  Consumer  United States     Fairfield          Ohio
# 9984  Standard Class  Consumer  United States    Long Beach      New York
# 9985  Standard Class  Consumer  United States    Long Beach      New York
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# ...

# %%
# East = df[df['Region']=='East']
East.to_csv('east1.csv')

# %%
East.to_csv('east2.csv',index=False)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# if we want to check two condition then we used and logical operator
#general syntax:
# (df[Condation1) logic operator (df[Condtion2)
# (df['Region'] == 'South') & (df['Category'] == 'Furniture')    
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)
