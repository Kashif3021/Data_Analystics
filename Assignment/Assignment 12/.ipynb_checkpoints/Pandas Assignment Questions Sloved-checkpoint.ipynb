# %%
import pandas as pd

# %%
df = pd.read_csv('retail supermarket.csv')
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %% [markdown]
# ### 1- Find record if Sales greater than 500 and Quantity greater than 5?

# %%
df[(df['Sales'] > 500) & (df['Quantity'] > 5)]
# Out:
#            Ship Mode    Segment        Country           City         State  \
# 7     Standard Class   Consumer  United States    Los Angeles    California
# 10    Standard Class   Consumer  United States    Los Angeles    California
# 16    Standard Class   Consumer  United States        Madison     Wisconsin
# 27    Standard Class   Consumer  United States   Philadelphia  Pennsylvania
# 35       First Class  Corporate  United States     Richardson         Texas
# ...              ...        ...            ...            ...           ...
# 9879  Standard Class   Consumer  United States  New York City      New York
# 9925     First Class  Corporate  United States  New York City      New York
# 9942  Standard Class   Consumer  United States        Anaheim    California
# 9947    Second Class  Corporate  United States   Indianapolis       Indiana
# 9948    Second Class  Corporate  United States   Indianapolis       Indiana
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 7           90032     West       Technology       Phones   907.152         6
# 10          90032     West        Furniture       Tables  1706.184         9
# 16          53711  Central  Office Supplies      Storage   665.880         6
# 27          19140     East        Furniture    Bookcases  3083.430         7
# 35          75080  Central       Technology       Phones  1097.544         7
# ...           ...      ...              ...          ...       ...       ...
# 9879        10035     East        Furniture       Chairs   573.174         7
# 9925        10035     East  Office Supplies      Binders  1087.936         8
# 9942        92804     West  Office Supplies      Storage   998.820         9
# 9947        46203  Central        Furniture       Chairs  1925.880         6
# 9948        46203  Central  Office Supplies   Appliances  2405.200         8
#
#       Discount     Profit
# 7          0.2    90.7152
# 10         0.2    85.3092
# 16         0.0    13.3176
# 27         0.5 -1665.0522
# 35         0.2   123.4737
# ...        ...        ...
# 9879       0.1    63.6860
# 9925       0.2   353.5792
# 9942       0.0    29.9646
# 9947       0.0   539.2464
# 9948       0.0   793.7160
#
# [431 rows x 13 columns]

# %% [markdown]
# ### 2.Find records if Discount is more than 0.5 (50%) or Profit is negative.

# %%
df[(df['Discount']>0.5) or (df['Profit']<0)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4320\2293746159.py in ?()
# ----> 1 df[(df['Discount']>0.5) and (df['Profit']<0)]
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1578     @final
#    1579     def __nonzero__(self) -> NoReturn:
# -> 1580         raise ValueError(
#    1581             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1582             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1583         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  Central        Furniture    Bookcases  261.9600         2
# 1           42420  Central        Furniture       Chairs  731.9400         3
# 2           90036  Central  Office Supplies       Labels   14.6200         2
# 3           33311  Central        Furniture       Tables  957.5775         5
# 4           33311  Central  Office Supplies      Storage   22.3680         2
# ...           ...      ...              ...          ...       ...       ...
# 9989        33180  Central        Furniture  Furnishings   25.2480         3
# 9990        92627  Central        Furniture  Furnishings   91.9600         2
# 9991        92627  Central       Technology       Phones  258.5760         2
# 9992        92627  Central  Office Supplies        Paper   29.6000         4
# 9993        92683  Central  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %% [markdown]
#  ### How many records belong to the "Corporate" segment and the "Central" region?

# %%
# df['Segment'].unique()

# %%
df[(df['Segment']== 'Corporate') & (df['Region']== 'Central')]
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 2       Second Class  Corporate  United States  Los Angeles  California
# 21    Standard Class  Corporate  United States      Fremont    Nebraska
# 22    Standard Class  Corporate  United States      Fremont    Nebraska
# 35       First Class  Corporate  United States   Richardson       Texas
# 36       First Class  Corporate  United States   Richardson       Texas
# ...              ...        ...            ...          ...         ...
# 9964    Second Class  Corporate  United States       Newark    Delaware
# 9965    Second Class  Corporate  United States       Newark    Delaware
# 9966    Second Class  Corporate  United States       Newark    Delaware
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
#
#       Postal Code   Region         Category Sub-Category     Sales  Quantity  \
# 2           90036  Central  Office Supplies       Labels    14.620         2
# 21          68025  Central  Office Supplies          Art    19.460         7
# 22          68025  Central  Office Supplies   Appliances    60.340         7
# 35          75080  Central       Technology       Phones  1097.544         7
# 36          75080  Central        Furniture  Furnishings   190.920         5
# ...           ...      ...              ...          ...       ...       ...
# 9964        19711  Central        Furniture  Furnishings    13.400         1
# 9965        19711  Central  Office Supplies        Paper     4.980         1
# 9966        19711  Central  Office Supplies    Envelopes   109.690         7
# 9987        30605  Central       Technology  Accessories    79.990         1
# 9988        30605  Central       Technology       Phones   206.100         5
#
#       Discount    Profit
# 2          0.0    6.8714
# 21         0.0    5.0596
# 22         0.0   15.6884
# 35         0.2  123.4737
# 36         0.6 -147.9630
# ...        ...       ...
# 9964       0.0    6.4320
# 9965       0.0    2.3406
# 9966       0.0   51.5543
# 9987       0.0   28.7964
# 9988       0.0   55.6470
#
# [3020 rows x 13 columns]

# %% [markdown]
# ### Find all orders in the "Furniture" category but not in "Chairs" sub-category.
